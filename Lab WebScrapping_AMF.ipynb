# %% [markdown]
# ### LAB WEBSCRAPPING

# %%
from bs4 import BeautifulSoup
import requests ## HTTP REQUEST
import pandas as pd

# %%
url="https://www.billboard.com/charts/hot-100/"

# %%
response=requests.get(url)

# %%
response.status_code #ok
# Out:
# 200

# %%
soup=BeautifulSoup(response.content, "html.parser")

# %%
hit1=soup.find("h3", class_="c-title a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 u-font-size-23@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-245 u-max-width-230@tablet-only u-letter-spacing-0028@tablet").get_text()

# %%
hit1=hit1.replace("\t","").replace("\n","")

# %%
artist_hit1=soup.find("span", class_="c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only u-font-size-20@tablet").get_text()

# %%
artist_hit1=artist_hit1.replace("\t","").replace("\n","")

# %%
titulos=soup.find_all("h3", class_="c-title a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only", id="title-of-a-story")

# %%
titulos #ok!
# Out:
# [<h3 class="c-title a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only" id="title-of-a-story">
#
#
#
#
#  					Too Sweet
#
#  </h3>,
#  <h3 class="c-title a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only" id="title-of-a-story">
#
#
#
#
#  					Beautiful Things
#
#  </h3>,
#  <h3 class="c-title a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only" id="title-of-a-story">
#
#
#
#
#  					Lose Control
#
#  </h3>,
# ...

# %%
len(titulos) #falta uno porque el primer título está puesto de otra manera
# Out:
# 99

# %%
titulos_canciones=[]
for i in titulos:
    titulos_canciones.append(i.get_text())

# %%
titulos_canciones
# Out:
# ['\n\n\t\n\t\n\t\t\n\t\t\t\t\tToo Sweet\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tBeautiful Things\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tLose Control\t\t\n\t\n',
#  "\n\n\t\n\t\n\t\t\n\t\t\t\t\tTexas Hold 'Em\t\t\n\t\n",
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\t7 Minute Drill\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tLovin On Me\t\t\n\t\n',
#  "\n\n\t\n\t\n\t\t\n\t\t\t\t\tWe Can't Be Friends (Wait For Your Love)\t\t\n\t\n",
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tType Shit\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tStick Season\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tWanna Be\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tI Remember Everything\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tCruel Summer\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tGreedy\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSaturn\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tI Like The Way You Kiss Me\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tCarnival\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tAgora Hills\t\t\n\t\n',
# ...

# %%
canciones_clean=[]
for i in titulos_canciones:
    canciones_clean.append(i.replace("\t","").replace("\n",""))

# %%
canciones_clean
# Out:
# ['Too Sweet',
#  'Beautiful Things',
#  'Lose Control',
#  "Texas Hold 'Em",
#  '7 Minute Drill',
#  'Lovin On Me',
#  "We Can't Be Friends (Wait For Your Love)",
#  'Type Shit',
#  'Stick Season',
#  'Wanna Be',
#  'I Remember Everything',
#  'Cruel Summer',
#  'Greedy',
#  'Saturn',
#  'I Like The Way You Kiss Me',
#  'Carnival',
#  'Agora Hills',
#  'Crocodile Tearz',
#  'Snooze',
#  'Fast Car',
#  'Get It Sexyy',
#  'End Of Beginning',
#  'Water',
#  'Redrum',
#  'Feather',
#  'Man Made A Bar',
#  "Huntin' Wabbitz",
#  'Pricey',
#  'II Most Wanted',
#  'Never Lose Me',
#  'Austin',
#  'Made For Me',
#  'Whatever She Wants',
#  'H.Y.B.',
#  'Act II: Date @ 8',
#  'Cinderella',
#  "Ready '24",
#  'Yeah Glo!',
#  'Slow It Down',
#  'Where The Wild Things Are',
#  'Burn It Down',
#  'Obsessed',
#  'Where It Ends',
#  'Houdini',
#  'Paint The Town Red',
#  'FE!N',
#  'Gata Only',
#  'Wild Ones',
#  'Selfish',
#  'Jolene',
#  '23',
#  'Stickz N Stonez',
#  'Scared To Start',
# ...

# %%
artista=soup.find_all("span", class_="c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only")

# %%
artista #ok!
# Out:
# [<span class="c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only">
#
#  	Hozier
#  </span>,
#  <span class="c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only">
#
#  	Benson Boone
#  </span>,
#  <span class="c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only">
#
#  	Teddy Swims
#  </span>,
# ...

# %%
len(artista) #por el mismo motivo, nos falta el primero, está en un formato diferente
# Out:
# 99

# %%
artista_cancion=[]
for i in artista:
    artista_cancion.append(i.get_text())

# %%
artista_cancion
# Out:
# ['\n\t\n\tHozier\n',
#  '\n\t\n\tBenson Boone\n',
#  '\n\t\n\tTeddy Swims\n',
#  '\n\t\n\tBeyonce\n',
#  '\n\t\n\tJ. Cole\n',
#  '\n\t\n\tJack Harlow\n',
#  '\n\t\n\tAriana Grande\n',
#  '\n\t\n\tFuture, Metro Boomin, Travis Scott & Playboi Carti\n',
#  '\n\t\n\tNoah Kahan\n',
#  '\n\t\n\tGloRilla & Megan Thee Stallion\n',
#  '\n\t\n\tZach Bryan Featuring Kacey Musgraves\n',
#  '\n\t\n\tTaylor Swift\n',
#  '\n\t\n\tTate McRae\n',
#  '\n\t\n\tSZA\n',
#  '\n\t\n\tArtemas\n',
#  '\n\t\n\t¥$: Ye & Ty Dolla $ign Featuring Rich The Kid & Playboi Carti\n',
#  '\n\t\n\tDoja Cat\n',
#  '\n\t\n\tJ. Cole\n',
#  '\n\t\n\tSZA\n',
#  '\n\t\n\tLuke Combs\n',
#  '\n\t\n\tSexyy Red\n',
#  '\n\t\n\tDjo\n',
#  '\n\t\n\tTyla\n',
#  '\n\t\n\t21 Savage\n',
#  '\n\t\n\tSabrina Carpenter\n',
#  '\n\t\n\tMorgan Wallen Featuring Eric Church\n',
#  '\n\t\n\tJ. Cole\n',
#  '\n\t\n\tJ. Cole Featuring Ari Lennox, Young Dro & Gucci Mane\n',
#  '\n\t\n\tBeyonce & Miley Cyrus\n',
#  '\n\t\n\tFlo Milli\n',
# ...

# %%
artista_clean=[]
for i in artista_cancion:
    artista_clean.append(i.replace("\t","").replace("\n",""))

# %%
artista_clean
# Out:
# ['Hozier',
#  'Benson Boone',
#  'Teddy Swims',
#  'Beyonce',
#  'J. Cole',
#  'Jack Harlow',
#  'Ariana Grande',
#  'Future, Metro Boomin, Travis Scott & Playboi Carti',
#  'Noah Kahan',
#  'GloRilla & Megan Thee Stallion',
#  'Zach Bryan Featuring Kacey Musgraves',
#  'Taylor Swift',
#  'Tate McRae',
#  'SZA',
#  'Artemas',
#  '¥$: Ye & Ty Dolla $ign Featuring Rich The Kid & Playboi Carti',
#  'Doja Cat',
#  'J. Cole',
#  'SZA',
#  'Luke Combs',
#  'Sexyy Red',
#  'Djo',
#  'Tyla',
#  '21 Savage',
#  'Sabrina Carpenter',
#  'Morgan Wallen Featuring Eric Church',
#  'J. Cole',
#  'J. Cole Featuring Ari Lennox, Young Dro & Gucci Mane',
#  'Beyonce & Miley Cyrus',
#  'Flo Milli',
#  'Dasha',
#  'Muni Long',
#  'Bryson Tiller',
#  'J. Cole Featuring Bas & Central Cee',
#  '4Batz Featuring Drake',
#  'Future, Metro Boomin & Travis Scott',
#  "J. Cole Featuring Cam'Ron",
#  'GloRilla',
#  'Benson Boone',
#  'Luke Combs',
#  'Parker McCollum',
#  'Olivia Rodrigo',
#  'Bailey Zimmerman',
# ...

# %%
billboard_hit=pd.DataFrame({"song":hit1, 
                    "artist":artist_hit1}, index=[0])

# %%
billboard=pd.DataFrame({"song":canciones_clean, 
                    "artist":artista_clean})

# %%
billboard_hit
# Out:
#         song                                 artist
# 0  Like That  Future, Metro Boomin & Kendrick Lamar

# %%
billboard
# Out:
#                 song                                artist
# 0          Too Sweet                                Hozier
# 1   Beautiful Things                          Benson Boone
# 2       Lose Control                           Teddy Swims
# 3     Texas Hold 'Em                               Beyonce
# 4     7 Minute Drill                               J. Cole
# ..               ...                                   ...
# 94          One Call                            Rich Amiri
# 95           We Ride                          Bryan Martin
# 96     Mamaw's House  Thomas Rhett Featuring Morgan Wallen
# 97          Let's Go                             Key Glock
# 98      16 Carriages                               Beyonce
#
# [99 rows x 2 columns]

# %%
billboard_final = pd.concat([billboard_hit, billboard], axis=0)

# %%
billboard_final
# Out:
#                 song                                 artist
# 0          Like That  Future, Metro Boomin & Kendrick Lamar
# 0          Too Sweet                                 Hozier
# 1   Beautiful Things                           Benson Boone
# 2       Lose Control                            Teddy Swims
# 3     Texas Hold 'Em                                Beyonce
# ..               ...                                    ...
# 94          One Call                             Rich Amiri
# 95           We Ride                           Bryan Martin
# 96     Mamaw's House   Thomas Rhett Featuring Morgan Wallen
# 97          Let's Go                              Key Glock
# 98      16 Carriages                                Beyonce
#
# [100 rows x 2 columns]

# %%
billboard_final.reset_index(inplace=True, drop=True)

# %%
billboard_final
# Out:
#                 song                                 artist
# 0          Like That  Future, Metro Boomin & Kendrick Lamar
# 1          Too Sweet                                 Hozier
# 2   Beautiful Things                           Benson Boone
# 3       Lose Control                            Teddy Swims
# 4     Texas Hold 'Em                                Beyonce
# ..               ...                                    ...
# 95          One Call                             Rich Amiri
# 96           We Ride                           Bryan Martin
# 97     Mamaw's House   Thomas Rhett Featuring Morgan Wallen
# 98          Let's Go                              Key Glock
# 99      16 Carriages                                Beyonce
#
# [100 rows x 2 columns]

# %%
billboard_final=billboard_final.map(str.lower)

# %%
billboard_final
# Out:
#                 song                                 artist
# 0          like that  future, metro boomin & kendrick lamar
# 1          too sweet                                 hozier
# 2   beautiful things                           benson boone
# 3       lose control                            teddy swims
# 4     texas hold 'em                                beyonce
# ..               ...                                    ...
# 95          one call                             rich amiri
# 96           we ride                           bryan martin
# 97     mamaw's house   thomas rhett featuring morgan wallen
# 98          let's go                              key glock
# 99      16 carriages                                beyonce
#
# [100 rows x 2 columns]

# %%
billboard_final[billboard_final['song'].str.contains('too sweet')]
# Out:
#         song  artist
# 1  too sweet  hozier

# %%
#FUNCION

# %%
def scrapeo():
   a=input("entra una canción:")
   a.lower
   while len(a)<3:
    a=input("entra una canción:")
   url="https://www.billboard.com/charts/hot-100/"
   response=requests.get(url)
   soup=BeautifulSoup(response.content, "html.parser")
   hit1=soup.find("h3", class_="c-title a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 u-font-size-23@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-245 u-max-width-230@tablet-only u-letter-spacing-0028@tablet").get_text()
   hit1=hit1.replace("\t","").replace("\n","")
   artist_hit1=soup.find("span", class_="c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only u-font-size-20@tablet").get_text()
   artist_hit1=artist_hit1.replace("\t","").replace("\n","")
   artist_hit1=soup.find("span", class_="c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only u-font-size-20@tablet").get_text()
   artist_hit1=artist_hit1.replace("\t","").replace("\n","")
   titulos=soup.find_all("h3", class_="c-title a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only", id="title-of-a-story")
   titulos_canciones=[]
   for i in titulos:
    titulos_canciones.append(i.get_text())
   canciones_clean=[]
   for i in titulos_canciones:
    canciones_clean.append(i.replace("\t","").replace("\n",""))
   artista=soup.find_all("span", class_="c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only")
   artista_cancion=[]   
   for i in artista:
    artista_cancion.append(i.get_text())
   artista_clean=[] 
   for i in artista_cancion:
    artista_clean.append(i.replace("\t","").replace("\n",""))
   billboard_hit=pd.DataFrame({"song":hit1, 
                    "artist":artist_hit1}, index=[0])
   billboard=pd.DataFrame({"song":canciones_clean, 
                    "artist":artista_clean})
   billboard_final = pd.concat([billboard_hit, billboard], axis=0)
   billboard_final.reset_index(inplace=True, drop=True)
   billboard_final=billboard_final.map(str.lower)
   x= billboard_final[billboard_final['song'].str.contains(a)]
   print(x)
   b=input('es esa la canción?:')
   if b=='yes':
    print("Esta canción está en el hot 100 de Billaboard")
   else: 
    print("no hemos sido capaces de encontrar tu canción")

# %%
scrapeo()
# Out:
#         song                                 artist
# 0  like that  future, metro boomin & kendrick lamar
# Esta canción está en el hot 100 de Billaboard
